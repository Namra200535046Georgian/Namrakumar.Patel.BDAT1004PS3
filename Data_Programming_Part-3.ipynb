# %% [markdown]
# ## <p style="text-align:center;">Data Programming Problem Set - 3</p>
# #### <p style="text-align:center;">Student Id : 200535046 <br> Name : Namrakumar Patel</p>

# %% [markdown]
# ## Question 1
# #### 1.1 Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1.2 Import the dataset & Assign it to a variable called users

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
users = pd.read_csv(url, sep='|')
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# #### 1.3 Discover what is the mean age per occupation

# %%
mean_age_per_occupation = users.groupby('occupation')['age'].mean()
mean_age_per_occupation
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# #### 1.4 Discover the Male ratio per occupation and sort it from the most to the least

# %%
# Calculate the male ratio per occupation
male_ratio_per_occupation = users.groupby('occupation')['gender'].apply(lambda x: (x == 'M').sum() / x.count())

# Sort the male ratio from the most to the least
sorted_male_ratio = male_ratio_per_occupation.sort_values(ascending=False)

print(sorted_male_ratio)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: gender, dtype: float64

# %% [markdown]
# #### 1.5 For each occupation, calculate the minimum and maximum ages

# %%
min_max_age_occupation = users.groupby('occupation')['age'].agg([('min_age', 'min'), ('max_age', 'max')])
print(min_max_age_occupation)
# Out:
#                min_age  max_age
# occupation
# administrator       21       70
# artist              19       48
# doctor              28       64
# educator            23       63
# engineer            22       70
# entertainment       15       50
# executive           22       69
# healthcare          22       62
# homemaker           20       50
# lawyer              21       53
# librarian           23       69
# marketing           24       55
# none                11       55
# other               13       64
# programmer          20       63
# retired             51       73
# salesman            18       66
# scientist           23       55
# student              7       42
# technician          21       55
# writer              18       60

# %% [markdown]
# #### 1.6 For each combination of occupation and sex, calculate the mean age

# %%
age_stats_per_occupation = users.groupby(['occupation', 'gender'])['age'].mean()

print(age_stats_per_occupation)
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# #### 1.7 For each occupation present the percentage of women and men

# %%
percentage_men_women = pd.crosstab(users['occupation'], users['gender'], normalize='index') * 100
print(percentage_men_women)
# Out:
# gender                 F           M
# occupation
# administrator  45.569620   54.430380
# artist         46.428571   53.571429
# doctor          0.000000  100.000000
# educator       27.368421   72.631579
# engineer        2.985075   97.014925
# entertainment  11.111111   88.888889
# executive       9.375000   90.625000
# healthcare     68.750000   31.250000
# homemaker      85.714286   14.285714
# lawyer         16.666667   83.333333
# librarian      56.862745   43.137255
# marketing      38.461538   61.538462
# none           44.444444   55.555556
# other          34.285714   65.714286
# programmer      9.090909   90.909091
# retired         7.142857   92.857143
# salesman       25.000000   75.000000
# scientist       9.677419   90.322581
# student        30.612245   69.387755
# technician      3.703704   96.296296
# writer         42.222222   57.777778

# %% [markdown]
# ## Question 2
# #### 2.1 Import the necessary libraries, Import the dataset, and Assign it to a variable called euro12

# %%
import numpy as np
import pandas as pd

url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"
euro12 = pd.read_csv(url)
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### 2.2 Select only the Goal column

# %%
goals = euro12["Goals"]
print(goals)
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# #### 2.3 How many team participated in the Euro2012?

# %%
euro12.shape[0]
# Out:
# 16

# %% [markdown]
# #### 2.4 What is the number of columns in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# #### 2.5 View only the columns Team, Yellow Cards and Red Cards and assign the to a dataframe called discipline

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# #### 2.6 Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline_sorted = discipline.sort_values(by=['Red Cards', 'Yellow Cards'], ascending = False)
print(discipline_sorted)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# #### 2.7 Calculate the mean Yellow Cards given per Team

# %%
mean_yellow_cards = discipline.groupby('Team')['Yellow Cards'].mean()
print(mean_yellow_cards)
# Out:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %% [markdown]
# #### 2.8  Filter teams that scored more than 6 goals

# %%
team_goals = euro12[euro12['Goals']>6]['Team']
print(team_goals)
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# #### 2.9 Select the first 7 columns

# %%
seven_column = euro12.iloc[:, :7]
seven_column
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### 2.10 Select all columns except the last 3

# %%
not_last_three_column = euro12.iloc[:, :-3]
not_last_three_column
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# #### 2.10 Present only the Shooting Accuracy from England, Italy and Russia

# %%
shooting_accuracy = euro12[euro12['Team'].isin(['England', 'Italy', 'Russia'])]['Shooting Accuracy']
shooting_accuracy
# Out:
# 3     50.0%
# 7     43.0%
# 12    22.5%
# Name: Shooting Accuracy, dtype: object

# %% [markdown]
# ## Question 3

# %% [markdown]
# #### 3.1 Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 3.2  Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
#
# • The second a random number from 1 to 3
#
# • The third a random number from 10,000 to 30,000

# %%
# 100 is a length of series
series_1 = pd.Series(np.random.randint(1, 5, 100))
series_2 = pd.Series(np.random.randint(1, 4, 100))
series_3 = pd.Series(np.random.randint(10000, 30001, 100))

# %%
print(series_1)
# Out:
# 0     1
# 1     3
# 2     4
# 3     3
# 4     1
#      ..
# 95    4
# 96    4
# 97    1
# 98    2
# 99    2
# Length: 100, dtype: int32

# %% [markdown]
# #### 3.3 Create a DataFrame by joinning the Series by column

# %%
df = pd.concat([series_1, series_2, series_3], axis = 1)

# %%
df.head()
# Out:
#    0  1      2
# 0  1  1  18483
# 1  3  2  14606
# 2  4  1  22622
# 3  3  1  11465
# 4  1  3  13948

# %% [markdown]
# #### 3.4 Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']

# %%
df.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      1       1            18483
# 1      3       2            14606
# 2      4       1            22622
# 3      3       1            11465
# 4      1       3            13948

# %% [markdown]
# #### 3.5 Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
bigColumn = pd.concat([series_1, series_2, series_3], ignore_index=False, axis = 0)
df_bigColumn = pd.DataFrame({'bigcolumn': bigColumn})
df_bigColumn.head()
# Out:
#    bigcolumn
# 0          1
# 1          3
# 2          4
# 3          3
# 4          1

# %% [markdown]
# #### 3.6 Ops it seems it is going only until index 99. Is it true?
# > Yes, it is true. You can check the same through below code. It's been fixed using reset_index function

# %%
df_bigColumn
# Out:
#     bigcolumn
# 0           1
# 1           3
# 2           4
# 3           3
# 4           1
# ..        ...
# 95      16183
# 96      10830
# 97      22037
# 98      15639
# 99      19441
#
# [300 rows x 1 columns]

# %% [markdown]
# #### 3.7 Reindex the DataFrame so it goes from 0 to 299

# %%
df_bigColumn = df_bigColumn.reset_index(drop=True)

# %%
df_bigColumn
# Out:
#      bigcolumn
# 0            1
# 1            3
# 2            4
# 3            3
# 4            1
# ..         ...
# 295      16183
# 296      10830
# 297      22037
# 298      15639
# 299      19441
#
# [300 rows x 1 columns]

# %% [markdown]
# ## Question 4

# %% [markdown]
# #### Wind Statistics
# > The data have been modified to contain some missing values, identified by NaN. Using pandas should make this exercise easier, in particular for the bonus question

# %% [markdown]
# #### 4.1  Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 4.2 Import the dataset from the attached file wind.txt

# %%
df = pd.read_csv('C://Users//patel//Downloads//BDAT Assignment//data.txt', delim_whitespace=True)
df
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# #### 4.3 Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv('C://Users//patel//Downloads//BDAT Assignment//data.txt',sep = '\s+',parse_dates=[[0,1,2]])

data = data.rename(columns={'Yr_Mo_Dy': 'DATE'})

# %%
data
# Out:
#            DATE    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %%
data['DATE'] = pd.to_datetime(data['DATE'], format='%Y_%m_%d')
data = data.set_index('DATE')

data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# DATE
# 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# DATE
# 2061-01-01  12.58  18.50  15.04
# 2061-01-02   9.67  17.54  13.83
# 2061-01-03   7.67  12.75  12.71
# 2061-01-04   5.88   5.46  10.88
# 2061-01-05  10.34  12.92  11.83

# %% [markdown]
# #### 4.4 Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
def fix_date_year(x):
    year = x.year - 100 if x.year > 1989 else x.year
    return pd.to_datetime(year * 10000 + x.month * 100 + x.day, format='%Y%m%d')

# Apply the function to fix the year in the date column
data.index = data.index.map(fix_date_year)

data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# DATE
# 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# DATE
# 1961-01-01  12.58  18.50  15.04
# 1961-01-02   9.67  17.54  13.83
# 1961-01-03   7.67  12.75  12.71
# 1961-01-04   5.88   5.46  10.88
# 1961-01-05  10.34  12.92  11.83

# %% [markdown]
# #### 4.5  Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='DATE', length=6574, freq=None)

# %% [markdown]
# #### 4.6 Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

# %%
data.isna().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# #### 4.7 Compute how many non-missing values there are in total

# %%
data.notna().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
data.notna().sum().sum()
# Out:
# 78857

# %% [markdown]
# #### 4.8 Calculate the mean windspeeds of the windspeeds over all the locations and all the times.

# %%
data.mean()
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %%
data.mean().mean()
# Out:
# 10.227982360836938

# %% [markdown]
# #### 4.9 Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days

# %%
loc_stats = pd.DataFrame({
    'min': data.min(),
    'max': data.max(),
    'mean': data.mean(),
    'std': data.std()
    })

# %%
loc_stats
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %% [markdown]
# #### 4.10  Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.

# %%
day_stats = pd.DataFrame({
    'min': data.min(axis=1),
    'max': data.max(axis=1),
    'mean': data.mean(axis=1),
    'std': data.std(axis=1)
})

day_stats
# Out:
#              min    max       mean       std
# DATE
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# #### 4.11 Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.

# %%
jan_df = data[data.index.month == 1]
jan_df.mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# #### 4.12 Downsample the record to a yearly frequency for each location.

# %%
yearly_df = data.resample('AS').mean()
yearly_df
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# DATE
# 1961-01-01  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-01-01  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-01-01  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-01-01  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-01-01  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-01-01  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-01-01  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-01-01  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-01-01  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-01-01  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-01-01  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# #### 4.13 Downsample the record to a monthly frequency for each location

# %%
monthly_df = data.resample('M').mean()
monthly_df
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# DATE
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# #### 4.14 Downsample the record to a weekly frequency for each location.

# %%
weekly_df = data.resample('W').mean()
weekly_df
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# DATE
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %% [markdown]
# #### 4.15 Min, max, mean, and standard deviation for each week for the first 52 weeks

# %%
weekly_stats = data.resample('W').agg(['min', 'max', 'mean', 'std'])
weekly_stats = weekly_stats.loc['1961-01-02':'1961-12-31']  # select the first 52 weeks
weekly_stats
# Out:
#               RPT                                VAL                    \
#               min    max       mean       std    min    max       mean
# DATE
# 1961-01-08  10.58  18.50  13.541429  2.631321   6.63  16.88  11.486667
# 1961-01-15   9.04  19.75  12.468571  3.555392   3.54  12.08   8.967143
# 1961-01-22   4.92  19.83  13.204286  5.337402   3.42  14.37   9.862857
# 1961-01-29  13.62  25.04  19.880000  4.619061   9.96  23.91  16.141429
# 1961-02-05  10.58  24.21  16.827143  5.251408   9.46  24.21  15.460000
# 1961-02-12  16.00  24.54  19.684286  3.587677  11.54  21.42  16.417143
# 1961-02-19   6.04  22.50  15.130000  5.064609  11.63  20.17  15.091429
# 1961-02-26   7.79  25.80  15.221429  7.020716   7.08  21.50  13.625714
# 1961-03-05  10.96  13.33  12.101429  0.997721   8.83  17.00  12.951429
# 1961-03-12   4.88  14.79   9.376667  3.732263   8.08  16.96  11.578571
# 1961-03-19   4.92  16.88  11.911429  3.860036   9.46  15.54  13.501429
# ...

# %% [markdown]
# ## Question 5
# #### 5.1 Import the necessary libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# #### 5.2 Import the dataset from this address.
# #### 5.3 Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv' ,sep = '\t' )
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# #### 5.4 see the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# #### 5.5 What is the number of observations in the dataset?

# %%
chipo.shape[0]
# Out:
# 4622

# %% [markdown]
# #### 5.6 What is the number of column in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# #### 5.7 print all the name of the columns

# %%
for column in chipo.columns:
    print(column)
# Out:
# order_id
# quantity
# item_name
# choice_description
# item_price

# %% [markdown]
# #### 5.8 how is the dataset indexed

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# #### 5.9 Which was the most-ordered item?

# %%
most_order_counts = chipo.groupby('item_name').sum()
most_order_counts = most_order_counts.sort_values(['quantity'], ascending=False)
most_order_counts.head(1)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_20568\3095960704.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   most_order_counts = chipo.groupby('item_name').sum()
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %% [markdown]
# #### 5.10 For the most-ordered item, how many items were ordered?

# %%
most_order_counts.head(1).quantity
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %% [markdown]
# #### 5.11 What was the most ordered item in the choice_description column?

# %%
most_order_choice_description = chipo.groupby('choice_description').sum()
most_order_choice_description = most_order_choice_description.sort_values(['quantity'], ascending=False)
most_order_choice_description.head(1)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_20568\2151564411.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   most_order_choice_description = chipo.groupby('choice_description').sum()
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %% [markdown]
# #### 5.12  How many items were orderd in total?

# %%
chipo['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# #### 5.13
# • Turn the item price into a float
#
# • Check the item price type
#
# • Create a lambda function and change the type of item price
#
# • Check the item price type

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:-1]))
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ####  5.14 How much was the revenue for the period in the dataset?

# %%
revenue = (chipo['quantity'] * chipo['item_price']).sum()
revenue
# Out:
# 39237.02

# %% [markdown]
# #### 5.15 How many orders were made in the period?

# %%
total_orders = chipo['order_id'].nunique()
total_orders
# Out:
# 1834

# %% [markdown]
# #### 5.16 What is the average revenue amount per order?

# %%
revenue/total_orders
# Out:
# 21.39423118865867

# %% [markdown]
# #### 5.17 How many different items are sold?

# %%
chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# ## Question 6
# > Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_6 = pd.read_csv('us-marriages-divorces-1867-2014.csv')
df_6.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
# Set the year column as the index
df_6.set_index('Year', inplace=True)

# Create a line plot showing the number of marriages and divorces per capita
plt.plot(df_6['Marriages_per_1000'], label='Marriages')
plt.plot(df_6['Divorces_per_1000'], label='Divorces')

# Add labels and legend
plt.title('Marriages and Divorces per Capita in the U.S. between 1867 and 2014')
plt.xlabel('Year')
plt.ylabel('Number per 1000')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ## Question 7
# > Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_7 = pd.read_csv('us-marriages-divorces-1867-2014.csv')
df_7.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
years = [1900, 1950, 2000]
df_7 = df_7[df_7.Year.isin(years)]


fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(df_7.Year, df_7.Marriages_per_1000, width=3, align='edge', label='Marriages per capita')
ax.bar(df_7.Year, df_7.Divorces_per_1000, width=-3, align='edge', label='Divorces per capita')


ax.set_xlabel('Year')
ax.set_ylabel('Per capita')
ax.set_title('Marriages and Divorces per capita in the U.S. between 1900, 1950, and 2000')
ax.legend()
plt.show()

# %% [markdown]
# ## Question 8
# > Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.

# %%
df_8 = pd.read_csv("actor_kill_counts.csv")
df_8
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
# Sort the data by kill count
df_8 = df_8.sort_values('Count', ascending=False)

# Create the horizontal bar chart
plt.barh(df_8['Actor'], df_8['Count'], color='orange')

# Add labels to the chart
plt.xlabel('Kill Count')
plt.ylabel('Actor')
plt.title('Deadliest Actors in Hollywood')

# Display the chart
plt.show()

# %% [markdown]
# ## Question 9
# > Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
#
# > Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
df_9 = pd.read_csv("roman-emperor-reigns.csv")
df_9
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
# the count of emperors in each cause of death category
cause_counts = df_9['Cause_of_Death'].value_counts()

# plotting a pie chart
plt.figure(figsize=(8, 8))
plt.pie(cause_counts, labels=cause_counts.index, autopct='%1.1f%%', startangle=140)

# title of the plot
plt.title('Fraction of Roman Emperors by Cause of Death')

# Equal aspect ratio ensures that the pie chart is circular
plt.axis('equal')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Question 10
# > Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009

# %%
df_10 = pd.read_csv("arcade-revenue-vs-cs-doctorates.csv")

# %%
# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df_10['Total Arcade Revenue (billions)'], df_10['Computer Science Doctorates Awarded (US)'],
            c=df_10['Year'], cmap='viridis', s=100, edgecolors='k', alpha=0.7)

# Add labels and title
plt.xlabel('Total Arcade Revenue (billions)')
plt.ylabel('Computer Science Doctorates Awarded (US)')
plt.title('Relationship between Arcade Revenue and CS Doctorates Awarded between 2000 and 2009')
plt.colorbar(label='Year')

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()
